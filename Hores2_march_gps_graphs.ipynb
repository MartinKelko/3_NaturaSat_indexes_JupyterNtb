# %% [markdown]
# NDPI - Normalized Difference Pond Index

# %%
import pandas as pd

# Displaying the table
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDPI_Hores2_march_gps.xlsx')
df
# Out:
#    Curve_name       Min       Max      Mean
# 0   023731 PM  0.000000  0.000000  0.000000
# 1   030637 PM  0.030844  0.153017  0.080673
# 2   031602 PM  0.003120  0.124249  0.049057
# 3   032159 PM  0.026350  0.119924  0.061969
# 4   032745 PM  0.045566  0.064339  0.052508
# 5   033058 PM  0.021061  0.096149  0.059324
# 6   033605 PM  0.106554  0.126320  0.114960
# 7   034013 PM  0.070320  0.092010  0.081644
# 8   034444 PM -0.022483  0.127193  0.052319
# 9   035226 PM -0.240626  0.128968 -0.080832
# 10  040332 PM  0.013365  0.115667  0.050120
# 11  040642 PM  0.097096  0.119963  0.108321
# 12  043911 PM  0.043106  0.147519  0.094895
# 13  051524 PM  0.088064  0.183360  0.122345
# 14  052056 PM  0.047380  0.172115  0.118963
# 15  052409 PM  0.040407  0.147429  0.101371
# 16  052713 PM -0.022373  0.130308  0.056754
# 17  053002 PM  0.000835  0.084126  0.053972

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file into a DataFrame
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDPI_Hores2_march_gps.xlsx')

# Set Curve_name as the index for easier plotting
df.set_index('Curve_name', inplace=True)

# Plotting with custom colors
ax = df.plot(kind='bar', figsize=(10, 5), color=['blue', 'green', 'orange'])
plt.title('24-03-14 | NDPI - Normalized Difference Pond Index')
plt.xlabel('Curve_name')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.grid(True)
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# NDTI - Normalized Difference Turbidity Index

# %%
import pandas as pd

# Displaying the table
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDTI_Hores2_march_gps.xlsx')
df
# Out:
#    Curve_name       Min       Max      Mean
# 0   023731 PM  0.000000  0.000000  0.000000
# 1   030637 PM -0.041702 -0.014485 -0.028785
# 2   031602 PM -0.052482 -0.026302 -0.037345
# 3   032159 PM -0.039299 -0.022821 -0.033309
# 4   032745 PM -0.032326 -0.027945 -0.029908
# 5   033058 PM -0.039844 -0.031517 -0.035933
# 6   033605 PM -0.016385 -0.014941 -0.015651
# 7   034013 PM -0.043921 -0.022959 -0.032547
# 8   034444 PM -0.035892 -0.019147 -0.024309
# 9   035226 PM -0.049660 -0.007637 -0.025617
# 10  040332 PM -0.015865 -0.005081 -0.012100
# 11  040642 PM -0.020983 -0.018424 -0.020216
# 12  043911 PM -0.043430 -0.012307 -0.030319
# 13  051524 PM -0.019179  0.000494 -0.008472
# 14  052056 PM -0.018767 -0.008350 -0.014083
# 15  052409 PM -0.024571 -0.010566 -0.017884
# 16  052713 PM -0.028213 -0.009534 -0.018568
# 17  053002 PM -0.031017 -0.016676 -0.025763

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file into a DataFrame
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDTI_Hores2_march_gps.xlsx')

# Set Curve_name as the index for easier plotting
df.set_index('Curve_name', inplace=True)

# Plotting with custom colors
ax = df.plot(kind='bar', figsize=(10, 5), color=['blue', 'green', 'orange'])
plt.title('24-03-14 | NDTI - Normalized Difference Turbidity Index')
plt.xlabel('Curve_name')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.grid(True)
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# NDVI - Normalized Difference Vegetation Index

# %%
import pandas as pd

# Displaying the table
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDVI_Hores2_march_gps.xlsx')
df
# Out:
#    Curve_name       Min       Max      Mean
# 0   023731 PM  0.000000  0.000000  0.000000
# 1   030637 PM  0.080296  0.166302  0.121209
# 2   031602 PM  0.098272  0.135688  0.121224
# 3   032159 PM  0.098029  0.152195  0.130869
# 4   032745 PM  0.104267  0.136643  0.122279
# 5   033058 PM  0.126761  0.149625  0.135286
# 6   033605 PM  0.127809  0.166233  0.146553
# 7   034013 PM  0.110613  0.161682  0.135086
# 8   034444 PM  0.067621  0.175713  0.120816
# 9   035226 PM -0.039809  0.169633  0.044547
# 10  040332 PM  0.076636  0.170844  0.106820
# 11  040642 PM  0.100145  0.128075  0.109860
# 12  043911 PM  0.085804  0.224080  0.138598
# 13  051524 PM  0.063458  0.108631  0.082841
# 14  052056 PM  0.079861  0.106439  0.090738
# 15  052409 PM  0.069182  0.084253  0.078647
# 16  052713 PM  0.078463  0.085378  0.082052
# 17  053002 PM  0.053686  0.088165  0.064993

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file into a DataFrame
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDVI_Hores2_march_gps.xlsx')

# Set Curve_name as the index for easier plotting
df.set_index('Curve_name', inplace=True)

# Plotting with custom colors
ax = df.plot(kind='bar', figsize=(10, 5), color=['blue', 'green', 'orange'])
plt.title('24-03-14 | NDVI - Normalized Difference Vegetation Index')
plt.xlabel('Curve_name')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.grid(True)
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# NDWI - Normalized Difference Water Index

# %%
import pandas as pd

# Displaying the table
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDWI_Hores2_march_gps.xlsx')
df
# Out:
#    Curve_name       Min       Max      Mean
# 0   023731 PM  0.000000  0.000000  0.000000
# 1   030637 PM -0.152183 -0.053309 -0.092761
# 2   031602 PM -0.103758 -0.046027 -0.084249
# 3   032159 PM -0.129825 -0.060788 -0.097993
# 4   032745 PM -0.104779 -0.076544 -0.092719
# 5   033058 PM -0.118667 -0.091352 -0.099837
# 6   033605 PM -0.150257 -0.112405 -0.131208
# 7   034013 PM -0.136556 -0.067018 -0.102975
# 8   034444 PM -0.157095 -0.041687 -0.096798
# 9   035226 PM -0.150633  0.073970 -0.019026
# 10  040332 PM -0.155400 -0.061553 -0.094860
# 11  040642 PM -0.107699 -0.079516 -0.089846
# 12  043911 PM -0.182425 -0.049189 -0.108801
# 13  051524 PM -0.100859 -0.052268 -0.074421
# 14  052056 PM -0.098177 -0.064808 -0.076747
# 15  052409 PM -0.073752 -0.050734 -0.060846
# 16  052713 PM -0.074308 -0.052023 -0.063575
# 17  053002 PM -0.058187 -0.026558 -0.039299

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file into a DataFrame
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDWI_Hores2_march_gps.xlsx')

# Set Curve_name as the index for easier plotting
df.set_index('Curve_name', inplace=True)

# Plotting with custom colors
ax = df.plot(kind='bar', figsize=(10, 5), color=['blue', 'green', 'orange'])
plt.title('24-03-14 | NDWI - Normalized Difference Water Index')
plt.xlabel('Curve_name')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.grid(True)
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# NDWI2 - Normalized Difference Water Index 2

# %%
import pandas as pd

# Displaying the table
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDWI2_Hores2_march_gps.xlsx')
df
# Out:
#    Curve_name       Min       Max      Mean
# 0   023731 PM  0.000000  0.000000  0.000000
# 1   030637 PM -0.153017 -0.030844 -0.080673
# 2   031602 PM -0.124249 -0.003120 -0.049057
# 3   032159 PM -0.119924 -0.026350 -0.061969
# 4   032745 PM -0.064339 -0.045566 -0.052508
# 5   033058 PM -0.096149 -0.021061 -0.059324
# 6   033605 PM -0.126320 -0.106554 -0.114960
# 7   034013 PM -0.092010 -0.070320 -0.081644
# 8   034444 PM -0.127193  0.022483 -0.052319
# 9   035226 PM -0.128968  0.240626  0.080832
# 10  040332 PM -0.115667 -0.013365 -0.050120
# 11  040642 PM -0.119963 -0.097096 -0.108321
# 12  043911 PM -0.147519 -0.043106 -0.094895
# 13  051524 PM -0.183360 -0.088064 -0.122345
# 14  052056 PM -0.172115 -0.047380 -0.118963
# 15  052409 PM -0.147429 -0.040407 -0.101371
# 16  052713 PM -0.130308  0.022373 -0.056754
# 17  053002 PM -0.084126 -0.000835 -0.053972

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file into a DataFrame
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDWI2_Hores2_march_gps.xlsx')

# Set Curve_name as the index for easier plotting
df.set_index('Curve_name', inplace=True)

# Plotting with custom colors
ax = df.plot(kind='bar', figsize=(10, 5), color=['blue', 'green', 'orange'])
plt.title('24-03-14 | NDWI2 - Normalized Difference Water Index 2')
plt.xlabel('Curve_name')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.grid(True)
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()

# %% [markdown]
# NDWI3 - Normalized Difference Water Index 3

# %%
import pandas as pd

# Displaying the table
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDWI3_Hores2_march_gps.xlsx')
df
# Out:
#    Curve_name       Min       Max      Mean
# 0   023731 PM  0.000000  0.000000  0.000000
# 1   030637 PM  0.063211  0.179008  0.123613
# 2   031602 PM  0.110319  0.193208  0.142522
# 3   032159 PM  0.101574  0.169246  0.147520
# 4   032745 PM  0.132867  0.179009  0.160369
# 5   033058 PM  0.099951  0.188184  0.154154
# 6   033605 PM  0.111409  0.147310  0.131371
# 7   034013 PM  0.084671  0.175181  0.143260
# 8   034444 PM  0.120725  0.198600  0.148449
# 9   035226 PM  0.079727  0.276323  0.177347
# 10  040332 PM  0.124912  0.204737  0.156797
# 11  040642 PM  0.079772  0.126780  0.099323
# 12  043911 PM  0.078902  0.251425  0.141291
# 13  051524 PM  0.012127  0.066190  0.039715
# 14  052056 PM -0.007070  0.088088  0.047680
# 15  052409 PM  0.032227  0.078736  0.051303
# 16  052713 PM  0.022576  0.154938  0.095857
# 17  053002 PM  0.041919  0.102498  0.069412

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file into a DataFrame
df = pd.read_excel('C:\\NaturaSat_Kelko\\Naturasat_Kelko\\Hores2_march_gps\\NDWI3_Hores2_march_gps.xlsx')

# Set Curve_name as the index for easier plotting
df.set_index('Curve_name', inplace=True)

# Plotting with custom colors
ax = df.plot(kind='bar', figsize=(10, 5), color=['blue', 'green', 'orange'])
plt.title('24-03-14 | NDWI3 - Normalized Difference Water Index 3')
plt.xlabel('Curve_name')
plt.ylabel('Values')
plt.xticks(rotation=90)
plt.grid(True)
plt.legend(title='Statistics')
plt.tight_layout()
plt.show()
